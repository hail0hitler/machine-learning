# %% [markdown]
# <a href="https://colab.research.google.com/github/hail0hitler/machine-learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data preprocessing in machine learning using pandas

# %%
import pandas as pd

data = {
    "cars":["BMW","Honda","BYD","Suzuki"],
    "model":["2007","2008","2020","1999"],
    "passengers":["4","2","6","4"]
}
data
# Out:
# {'cars': ['BMW', 'Honda', 'BYD', 'Suzuki'],
#  'model': ['2007', '2008', '2020', '1999'],
#  'passengers': ['4', '2', '6', '4']}

# %%
#convert the data dictionary to datatime
df=pd.DataFrame(data)
df
# Out:
#      cars model passengers
# 0     BMW  2007          4
# 1   Honda  2008          2
# 2     BYD  2020          6
# 3  Suzuki  1999          4

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/AI/pandaabhi.csv")

# %%
data={
    "calories":["420","500","390"],
    "duration":["50","60","45"]
}
data
# Out:
# {'calories': ['420', '500', '390'], 'duration': ['50', '60', '45']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   calories duration
# 0      420       50
# 1      500       60
# 2      390       45
